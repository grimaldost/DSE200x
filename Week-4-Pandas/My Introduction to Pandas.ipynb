# %% [markdown]
# # Pandas Notebook

# %%
import pandas as pd

# %%
ser = pd.Series([100,200,'bar',400,'foo'],['tom','bob','nancy','dan','eric'])
print(ser)
# Out:
# tom      100
# bob      200
# nancy    bar
# dan      400
# eric     foo
# dtype: object

# %%
ser.index
# Out:
# Index(['tom', 'bob', 'nancy', 'dan', 'eric'], dtype='object')

# %%
ser.loc[['nancy','bob']]
# Out:
# nancy    bar
# bob      200
# dtype: object

# %%
ser.iloc[[1,2,3]]
# Out:
# bob      200
# nancy    bar
# dan      400
# dtype: object

# %%
"nancy" in ser
# Out:
# True

# %%
ser*2
# Out:
# tom         200
# bob         400
# nancy    barbar
# dan         800
# eric     foofoo
# dtype: object

# %%
ser[[0,1,3]]**2
# Out:
# tom     10000
# bob     40000
# dan    160000
# dtype: object

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
d = {'one' : pd.Series([100.,200.,300.], ['apple','ball','clock']),
     'two' : pd.Series([111.,222.,333.,444.], ['apple','ball','cerill','dancy'])}

# %%
df = pd.DataFrame(d)
print(df)
# Out:
#           one    two
# apple   100.0  111.0
# ball    200.0  222.0
# cerill    NaN  333.0
# clock   300.0    NaN
# dancy     NaN  444.0

# %%
df.index
# Out:
# Index(['apple', 'ball', 'cerill', 'clock', 'dancy'], dtype='object')

# %%
df.columns
# Out:
# Index(['one', 'two'], dtype='object')

# %%
pd.DataFrame(d, index=['apple',"ball",'clock','bee'])
# Out:
#          one    two
# apple  100.0  111.0
# ball   200.0  222.0
# clock  300.0    NaN
# bee      NaN    NaN

# %%
pd.DataFrame(d, index=['apple',"ball",'clock'], columns=['two','five'])
# Out:
#          two five
# apple  111.0  NaN
# ball   222.0  NaN
# clock    NaN  NaN

# %%
data = [{'alex':1,'joe':2},{'ema':5,'dora':10,'alice':20}]
pd.DataFrame(data)
# Out:
#    alex  alice  dora  ema  joe
# 0   1.0    NaN   NaN  NaN  2.0
# 1   NaN   20.0  10.0  5.0  NaN

# %%
data = [{'alex':1,'joe':2},{'ema':5,'dora':10,'alice':20}]
pd.DataFrame(data,index=['orange','red'])
# Out:
#         alex  alice  dora  ema  joe
# orange   1.0    NaN   NaN  NaN  2.0
# red      NaN   20.0  10.0  5.0  NaN

# %%
data = [{'alex':1,'joe':2},{'ema':5,'dora':10,'alice':20}]
pd.DataFrame(data, columns=['joe','alice'])
# Out:
#    joe  alice
# 0  2.0    NaN
# 1  NaN   20.0

# %%
df
# Out:
#           one    two
# apple   100.0  111.0
# ball    200.0  222.0
# cerill    NaN  333.0
# clock   300.0    NaN
# dancy     NaN  444.0

# %%
df['one']
# Out:
# apple     100.0
# ball      200.0
# cerill      NaN
# clock     300.0
# dancy       NaN
# Name: one, dtype: float64

# %%
type(df['two'])
# Out:
# pandas.core.series.Series

# %%
df['three'] = df['one']*df['two']
df
# Out:
#           one    two    three
# apple   100.0  111.0  11100.0
# ball    200.0  222.0  44400.0
# cerill    NaN  333.0      NaN
# clock   300.0    NaN      NaN
# dancy     NaN  444.0      NaN

# %%
df['flag'] = df['one'] > 150
df
# Out:
#           one    two    three   flag
# apple   100.0  111.0  11100.0  False
# ball    200.0  222.0  44400.0   True
# cerill    NaN  333.0      NaN  False
# clock   300.0    NaN      NaN   True
# dancy     NaN  444.0      NaN  False

# %%
three = df.pop()
three
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-7d7189bb26cb> in <module>()
# ----> 1 three = df.pop()
#       2 three
#
# TypeError: pop() missing 1 required positional argument: 'item'

# %%
#del df['two']
df
# Out:
#           one   flag
# apple   100.0  False
# ball    200.0   True
# cerill    NaN  False
# clock   300.0   True
# dancy     NaN  False

# %%
df.insert(1,'copy_of_one',df['one'])
df
# Out:
#           one  copy_of_one   flag
# apple   100.0        100.0  False
# ball    200.0        200.0   True
# cerill    NaN          NaN  False
# clock   300.0        300.0   True
# dancy     NaN          NaN  False

# %%
df['Upper_half'] = df['one'][:2]
df
# Out:
#           one  copy_of_one   flag  Upper_half
# apple   100.0        100.0  False       100.0
# ball    200.0        200.0   True       200.0
# cerill    NaN          NaN  False         NaN
# clock   300.0        300.0   True         NaN
# dancy     NaN          NaN  False         NaN

# %%
# !ls ./movielens/
# Out:
# links.csv
# movies.csv
# ratings.csv
# README.txt
# tags.csv

# %%
# !cat ./movielens/movies.csv
# Out:
# movieId,title,genres
# 1,Toy Story (1995),Adventure|Animation|Children|Comedy|Fantasy
# 2,Jumanji (1995),Adventure|Children|Fantasy
# 3,Grumpier Old Men (1995),Comedy|Romance
# 4,Waiting to Exhale (1995),Comedy|Drama|Romance
# 5,Father of the Bride Part II (1995),Comedy
# 6,Heat (1995),Action|Crime|Thriller
# 7,Sabrina (1995),Comedy|Romance
# 8,Tom and Huck (1995),Adventure|Children
# 9,Sudden Death (1995),Action
# 10,GoldenEye (1995),Action|Adventure|Thriller
# 11,"American President, The (1995)",Comedy|Drama|Romance
# 12,Dracula: Dead and Loving It (1995),Comedy|Horror
# 13,Balto (1995),Adventure|Animation|Children
# 14,Nixon (1995),Drama
# 15,Cutthroat Island (1995),Action|Adventure|Romance
# 16,Casino (1995),Crime|Drama
# 17,Sense and Sensibility (1995),Drama|Romance
# 18,Four Rooms (1995),Comedy
# 19,Ace Ventura: When Nature Calls (1995),Comedy
# 20,Money Train (1995),Action|Comedy|Crime|Drama|Thriller
# 21,Get Shorty (1995),Comedy|Crime|Thriller
# ...

# %%
# !cat ./movielens/movies.csv | wc -l
# Out:
# 9126

# %%
# !head -11 ./movielens/movies.csv | tail -10
# Out:
# 1,Toy Story (1995),Adventure|Animation|Children|Comedy|Fantasy
# 2,Jumanji (1995),Adventure|Children|Fantasy
# 3,Grumpier Old Men (1995),Comedy|Romance
# 4,Waiting to Exhale (1995),Comedy|Drama|Romance
# 5,Father of the Bride Part II (1995),Comedy
# 6,Heat (1995),Action|Crime|Thriller
# 7,Sabrina (1995),Comedy|Romance
# 8,Tom and Huck (1995),Adventure|Children
# 9,Sudden Death (1995),Action
# 10,GoldenEye (1995),Action|Adventure|Thriller

# %%
movies = pd.read_csv('./movielens/movies.csv', sep=',')
type(movies)

movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
tags = pd.read_csv('./movielens/tags.csv', sep=',')
type(movies)

tags.head(10)
# Out:
#    userId  movieId                      tag   timestamp
# 0      15      339  sandra 'boring' bullock  1138537770
# 1      15     1955                  dentist  1193435061
# 2      15     7478                 Cambodia  1170560997
# 3      15    32892                  Russian  1170626366
# 4      15    34162              forgettable  1141391765
# 5      15    35957                    short  1141391873
# 6      15    37729               dull story  1141391806
# 7      15    45950               powerpoint  1169616291
# 8      15   100365                 activist  1425876220
# 9      15   100365              documentary  1425876220

# %%
ratings = pd.read_csv('./movielens/ratings.csv', sep=',')
type(ratings)

ratings.head(10)
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205
# 5       1     1263     2.0  1260759151
# 6       1     1287     2.0  1260759187
# 7       1     1293     2.0  1260759148
# 8       1     1339     3.5  1260759125
# 9       1     1343     2.0  1260759131

# %%
del tags['timestamp']
del ratings['timestamp']

# %%
row_0 = tags.iloc[0]
print(row_0)
# Out:
# userId                          15
# movieId                        339
# tag        sandra 'boring' bullock
# Name: 0, dtype: object

# %%
row_0['userId']
# Out:
# 15

# %%
'rating' in row_0
# Out:
# False

# %%
row_0 = row_0.rename('first_row')
row_0.name
# Out:
# 'first_row'

# %%
tags.head()
# Out:
#    userId  movieId                      tag
# 0      15      339  sandra 'boring' bullock
# 1      15     1955                  dentist
# 2      15     7478                 Cambodia
# 3      15    32892                  Russian
# 4      15    34162              forgettable

# %%
tags.index
# Out:
# RangeIndex(start=0, stop=1296, step=1)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
tags.iloc[[1,12,500]]
# Out:
#      userId  movieId         tag
# 1        15     1955     dentist
# 12       68     2174       music
# 500     364   109249  dark humor

# %%
ratings['rating'].describe()
# Out:
# count    100004.000000
# mean          3.543608
# std           1.058064
# min           0.500000
# 25%           3.000000
# 50%           4.000000
# 75%           4.000000
# max           5.000000
# Name: rating, dtype: float64

# %%
ratings.describe()
# Out:
#               userId        movieId         rating
# count  100004.000000  100004.000000  100004.000000
# mean      347.011310   12548.664363       3.543608
# std       195.163838   26369.198969       1.058064
# min         1.000000       1.000000       0.500000
# 25%       182.000000    1028.000000       3.000000
# 50%       367.000000    2406.500000       4.000000
# 75%       520.000000    5418.000000       4.000000
# max       671.000000  163949.000000       5.000000

# %%
ratings.mean()
# Out:
# userId       347.011310
# movieId    12548.664363
# rating         3.543608
# dtype: float64

# %%
ratings.min()
# Out:
# userId     1.0
# movieId    1.0
# rating     0.5
# dtype: float64

# %%
ratings.max()
# Out:
# userId        671.0
# movieId    163949.0
# rating          5.0
# dtype: float64

# %%
ratings.std()
# Out:
# userId       195.163838
# movieId    26369.198969
# rating         1.058064
# dtype: float64

# %%
ratings.mode()
# Out:
#    userId  movieId  rating
# 0     547      356     4.0

# %%
ratings.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000  0.007126  0.010467
# movieId  0.007126  1.000000 -0.028894
# rating   0.010467 -0.028894  1.000000

# %%
filter_1 = ratings['rating'] > 5
filter_1
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 99974     False
# 99975     False
# 99976     False
# 99977     False
# 99978     False
# 99979     False
# 99980     False
# 99981     False
# 99982     False
# 99983     False
# 99984     False
# 99985     False
# 99986     False
# 99987     False
# 99988     False
# 99989     False
# 99990     False
# 99991     False
# 99992     False
# 99993     False
# 99994     False
# 99995     False
# 99996     False
# 99997     False
# ...

# %%
filter_2 = (ratings['rating'] > 0)&(ratings['rating']<=5)
filter_2.all()
# Out:
# True

# %%
movies.shape
# Out:
# (9125, 3)

# %%
movies.isnull().all()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
ratings.shape
# Out:
# (100004, 3)

# %%
ratings.isnull().all()
# Out:
# userId     False
# movieId    False
# rating     False
# dtype: bool

# %%
tags.shape
# Out:
# (1296, 3)

# %%
tags.isnull().all()
# Out:
# userId     False
# movieId    False
# tag        False
# dtype: bool

# %%
tags = tags.dropna(axis=0)

# %%
tags.isnull().all()
# Out:
# userId     False
# movieId    False
# tag        False
# dtype: bool

# %%
# %matplotlib inline

# %%
ratings.hist(column='rating', figsize = (15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020BAB33DF98>]], dtype=object)

# %%
ratings.boxplot(column='rating',figsize=(15,10))

# %%
tags['tag'].head()
# Out:
# 0    sandra 'boring' bullock
# 1                    dentist
# 2                   Cambodia
# 3                    Russian
# 4                forgettable
# Name: tag, dtype: object

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
movies[['title', 'genres']].head()
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings[100:110]
# Out:
#      userId  movieId  rating
# 100       3      296     4.5
# 101       3      318     5.0
# 102       3      355     2.5
# 103       3      356     5.0
# 104       3      377     2.5
# 105       3      527     3.0
# 106       3      588     3.0
# 107       3      592     3.0
# 108       3      593     3.0
# 109       3      595     2.0

# %%
tag_counts = tags['tag'].value_counts()
tag_counts[-100:-90]
# Out:
# biblical                           1
# greed                              1
# philosophical issues               1
# adam sandler                       1
# Nudity (Full Frontal - Notable)    1
# alex pettyfer                      1
# hugh grant                         1
# India                              1
# lake forest                        1
# john cusack                        1
# Name: tag, dtype: int64

# %%
tag_counts[:10].plot(kind='bar',figsize=(15,10))

# %%
is_highly_rated = ratings['rating'] >=4

# %%
ratings[is_highly_rated][-10:]
# Out:
#         userId  movieId  rating
# 99988      671     5377     4.0
# 99989      671     5445     4.5
# 99991      671     5669     4.0
# 99992      671     5816     4.0
# 99994      671     5952     5.0
# 99995      671     5989     4.0
# 99996      671     5991     4.5
# 99997      671     5995     4.0
# 100000     671     6269     4.0
# 100001     671     6365     4.0

# %%
is_animation = movies['genres'].str
type(is_animation)
#movies[is_animation][:10]
# Out:
# pandas.core.strings.StringMethods

# %%
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating'], dtype='object')

# %%
ratings_count = ratings[['movieId','rating']].groupby('rating').count()
#type(ratings_count)
ratings_count
# Out:
#         movieId
# rating
# 0.5        1101
# 1.0        3326
# 1.5        1687
# 2.0        7271
# 2.5        4449
# 3.0       20064
# 3.5       10538
# 4.0       28750
# 4.5        7723
# 5.0       15095

# %%
average_rating = ratings[['movieId','rating']].groupby('movieId').mean()
average_rating.head(10)
# Out:
#            rating
# movieId
# 1        3.872470
# 2        3.401869
# 3        3.161017
# 4        2.384615
# 5        3.267857
# 6        3.884615
# 7        3.283019
# 8        3.800000
# 9        3.150000
# 10       3.450820

# %%
average_rating = ratings[['movieId','rating']].groupby('movieId').count()
average_rating.head(10)
# Out:
#          rating
# movieId
# 1           247
# 2           107
# 3            59
# 4            13
# 5            56
# 6           104
# 7            53
# 8             5
# 9            20
# 10          122

# %%
tags.head()
# Out:
#    userId  movieId                      tag
# 0      15      339  sandra 'boring' bullock
# 1      15     1955                  dentist
# 2      15     7478                 Cambodia
# 3      15    32892                  Russian
# 4      15    34162              forgettable

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
pd.concat([tags.head(6),movies.head()],axis=1,join='inner')
# Out:
#    userId  movieId                      tag  movieId  \
# 0      15      339  sandra 'boring' bullock        1
# 1      15     1955                  dentist        2
# 2      15     7478                 Cambodia        3
# 3      15    32892                  Russian        4
# 4      15    34162              forgettable        5
#
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
pd.concat([tags.head(),movies.head()],axis=0).loc[1]
# Out:
#                        genres  movieId      tag           title  userId
# 1                         NaN     1955  dentist             NaN    15.0
# 1  Adventure|Children|Fantasy        2      NaN  Jumanji (1995)     NaN

# %%
movies.merge(tags,on='movieId')
# Out:
#       movieId                                              title  \
# 0           1                                   Toy Story (1995)
# 1           5                 Father of the Bride Part II (1995)
# 2          47                        Seven (a.k.a. Se7en) (1995)
# 3          47                        Seven (a.k.a. Se7en) (1995)
# 4          47                        Seven (a.k.a. Se7en) (1995)
# 5          47                        Seven (a.k.a. Se7en) (1995)
# 6          47                        Seven (a.k.a. Se7en) (1995)
# 7          47                        Seven (a.k.a. Se7en) (1995)
# 8          47                        Seven (a.k.a. Se7en) (1995)
# 9          47                        Seven (a.k.a. Se7en) (1995)
# 10         47                        Seven (a.k.a. Se7en) (1995)
# 11         47                        Seven (a.k.a. Se7en) (1995)
# 12         50                         Usual Suspects, The (1995)
# ...

# %%
d = {'one' : pd.Series([100.,200.,300.,400]),
     'two' : pd.Series([111.,222.,333.,444.])}

# %%
df1 = pd.DataFrame(d)
df1
# Out:
#      one    two
# 0  100.0  111.0
# 1  200.0  222.0
# 2  300.0  333.0
# 3  400.0  444.0

# %%
c = {'one' : pd.Series([100.,200.,300.,400]),
     'three' : pd.Series([111.,222.,333.,444.,12131,123])}

# %%
df2 = pd.DataFrame(c)
df2
# Out:
#      one    three
# 0  100.0    111.0
# 1  200.0    222.0
# 2  300.0    333.0
# 3  400.0    444.0
# 4    NaN  12131.0
# 5    NaN    123.0

# %%
df2.merge(df1, on ='one', how = 'inner')
# Out:
#      one  three    two
# 0  100.0  111.0  111.0
# 1  200.0  222.0  222.0
# 2  300.0  333.0  333.0
# 3  400.0  444.0  444.0

# %%
avg_ratings = ratings.groupby('movieId', as_index=False).mean()
del avg_ratings['userId']
avg_ratings.head()
# Out:
#    movieId    rating
# 0        1  3.872470
# 1        2  3.401869
# 2        3  3.161017
# 3        4  2.384615
# 4        5  3.267857

# %%
box_office = movies.merge(avg_ratings, on = "movieId", how='inner')
box_office.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# rating     False
# dtype: bool

# %%
box_office.tail()
# Out:
#       movieId                                              title  \
# 9061   161944              The Last Brickmaker in America (2001)
# 9062   162376                                    Stranger Things
# 9063   162542                                      Rustom (2016)
# 9064   162672                                Mohenjo Daro (2016)
# 9065   163949  The Beatles: Eight Days a Week - The Touring Y...
#
#                        genres  rating
# 9061                    Drama     5.0
# 9062                    Drama     4.5
# 9063         Romance|Thriller     5.0
# 9064  Adventure|Drama|Romance     3.0
# 9065              Documentary     5.0

# %%
is_highly_rated = box_office['rating'] > 4
type(is_highly_rated)
# Out:
# pandas.core.series.Series

# %%
box_office[is_highly_rated].head()
# Out:
#     movieId                                              title  \
# 25       26                                     Othello (1995)
# 27       28                                  Persuasion (1995)
# 28       29  City of Lost Children, The (Cité des enfants p...
# 29       30  Shanghai Triad (Yao a yao yao dao waipo qiao) ...
# 39       41                                 Richard III (1995)
#
#                                     genres    rating
# 25                                   Drama  4.100000
# 27                           Drama|Romance  4.083333
# 28  Adventure|Drama|Fantasy|Mystery|Sci-Fi  4.025000
# 29                             Crime|Drama  4.050000
# 39                               Drama|War  4.021739

# %%
is_comedy = box_office['genres'].str.contains('Comedy')
type(is_comedy)
# Out:
# pandas.core.series.Series

# %%
box_office[is_comedy].head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 6        7                      Sabrina (1995)
#
#                                         genres    rating
# 0  Adventure|Animation|Children|Comedy|Fantasy  3.872470
# 2                               Comedy|Romance  3.161017
# 3                         Comedy|Drama|Romance  2.384615
# 4                                       Comedy  3.267857
# 6                               Comedy|Romance  3.283019

# %%
box_office[is_comedy & is_highly_rated].head()
# Out:
#      movieId                                        title  \
# 150      171                               Jeffrey (1995)
# 157      178                  Love & Human Remains (1993)
# 161      183                          Mute Witness (1994)
# 171      194                                 Smoke (1995)
# 204      232  Eat Drink Man Woman (Yin shi nan nu) (1994)
#
#                      genres    rating
# 150            Comedy|Drama  4.333333
# 157            Comedy|Drama  4.700000
# 161  Comedy|Horror|Thriller  5.000000
# 171            Comedy|Drama  4.291667
# 204    Comedy|Drama|Romance  4.208333

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies_genres = movies['genres'].str.split('|', expand=True)
movies_genres.head()
# Out:
#            0          1         2       3        4     5     6     7     8  \
# 0  Adventure  Animation  Children  Comedy  Fantasy  None  None  None  None
# 1  Adventure   Children   Fantasy    None     None  None  None  None  None
# 2     Comedy    Romance      None    None     None  None  None  None  None
# 3     Comedy      Drama   Romance    None     None  None  None  None  None
# 4     Comedy       None      None    None     None  None  None  None  None
#
#       9
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None

# %%
movies_genres['isComedy'] = movies['genres'].str.contains('Comedy')
movies_genres.head()
# Out:
#            0          1         2       3        4     5     6     7     8  \
# 0  Adventure  Animation  Children  Comedy  Fantasy  None  None  None  None
# 1  Adventure   Children   Fantasy    None     None  None  None  None  None
# 2     Comedy    Romance      None    None     None  None  None  None  None
# 3     Comedy      Drama   Romance    None     None  None  None  None  None
# 4     Comedy       None      None    None     None  None  None  None  None
#
#       9  isComedy
# 0  None      True
# 1  None     False
# 2  None      True
# 3  None      True
# 4  None      True

# %%
movies['year'] = movies['title'].str.extract('.*\((.*)\).*',expand=True)
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995

# %%
tags = pd.read_csv('./movielens/tags.csv')
tags.dtypes
# Out:
# userId        int64
# movieId       int64
# tag          object
# timestamp     int64
# dtype: object

# %%
tags['parsed_time'] = pd.to_datetime(tags['timestamp'], unit='s')
tags[100:120]
# Out:
#      userId  movieId                     tag   timestamp         parsed_time
# 100     176   104841                  sexist  1384107184 2013-11-10 18:13:04
# 101     179      260                   nerdy  1436669973 2015-07-12 02:59:33
# 102     179      260         Science Fiction  1436669968 2015-07-12 02:59:28
# 103     187     2082          Emilio Estevez  1233517175 2009-02-01 19:39:35
# 104     200      260    critically acclaimed  1437932756 2015-07-26 17:45:56
# 105     200      260         Science Fiction  1437932763 2015-07-26 17:46:03
# 106     200    80551  strong female presence  1438023607 2015-07-27 19:00:07
# 107     212     1061               emotional  1253930128 2009-09-26 01:55:28
# 108     212     1061                 revenge  1253930131 2009-09-26 01:55:31
# 109     212     1061              true story  1253930149 2009-09-26 01:55:49
# 110     212     1732               cult film  1253929373 2009-09-26 01:42:53
# ...

# %%
tags.dtypes
# Out:
# userId                  int64
# movieId                 int64
# tag                    object
# timestamp               int64
# parsed_time    datetime64[ns]
# dtype: object

# %%
greather_than_t = tags['parsed_time'] > '2015-02-01'

selected_rows = tags[greather_than_t]
selected_rows
# Out:
#       userId  movieId                                                tag  \
# 8         15   100365                                           activist
# 9         15   100365                                        documentary
# 10        15   100365                                             uganda
# 15        73   107999                                             action
# 16        73   107999                                              anime
# 17        73   107999                                            kung fu
# 18        73   111624                                              drama
# 19        73   111624                                              indie
# 20        73   111624                                               love
# 21        73   130682                                            b movie
# 22        73   130682                                             comedt
# 23        73   130682                                             horror
# ...

# %%
tags.sort_values(by='parsed_time',ascending=True).head()
# Out:
#      userId  movieId                                            tag  \
# 338     353    35836                                           dumb
# 0        15      339                        sandra 'boring' bullock
# 232     294    36401                                    fairy tales
# 229     294     6754                                        vampire
# 333     353     4721  As historicaly correct as Germany winning WW2
#
#       timestamp         parsed_time
# 338  1137217440 2006-01-14 05:44:00
# 0    1138537770 2006-01-29 12:29:30
# 232  1138983064 2006-02-03 16:11:04
# 229  1138983469 2006-02-03 16:17:49
# 333  1140389056 2006-02-19 22:44:16

# %%
avg_ratings = ratings.groupby(by='movieId', as_index=False).mean()
del avg_ratings['userId']
avg_ratings.head()
# Out:
#    movieId    rating
# 0        1  3.872470
# 1        2  3.401869
# 2        3  3.161017
# 3        4  2.384615
# 4        5  3.267857

# %%
joined = movies.merge(avg_ratings,on='movieId')
joined.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  year    rating
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995  3.872470
# 1                   Adventure|Children|Fantasy  1995  3.401869
# 2                               Comedy|Romance  1995  3.161017
# 3                         Comedy|Drama|Romance  1995  2.384615
# 4                                       Comedy  1995  3.267857

# %%
joined.corr()
# Out:
#           movieId    rating
# movieId  1.000000 -0.041213
# rating  -0.041213  1.000000

# %%
yerly_avg = joined[['year','rating']].groupby(by='year',as_index=False).mean()

# %%
yerly_avg
# Out:
#       year    rating
# 0     1902  4.333333
# 1     1915  3.000000
# 2     1916  3.500000
# 3     1917  4.250000
# 4     1918  4.250000
# 5     1919  3.000000
# 6     1920  2.500000
# 7     1921  4.387500
# 8     1922  3.926587
# 9     1923  4.166667
# 10    1924  4.360000
# 11    1925  3.928338
# 12    1926  3.708333
# 13    1927  3.903846
# 14    1928  4.292143
# 15    1929  3.240476
# 16    1930  3.718254
# 17    1931  3.798668
# 18    1932  3.303114
# 19    1933  4.075677
# 20    1934  3.325723
# 21    1935  3.644886
# 22    1936  3.453404
# 23    1937  3.752424
# 24    1938  3.549817
# 25    1939  3.747705
# 26    1940  3.667263
# 27    1941  3.782549
# 28    1942  3.659768
# 29    1943  3.542917
# ..     ...       ...
# 75    1988  3.242909
# 76    1989  3.245381
# 77    1990  3.166759
# 78    1991  3.214035
# 79    1992  3.335977
# 80    1993  3.281731
# 81    1994  3.269216
# 82    1995  3.337819
# 83    1996  3.260178
# 84    1997  3.183169
# 85    1998  3.266041
# ...

# %%
yerly_avg.plot(x='year',y='rating',figsize=(15,10),grid=True)

# %%
# %matplotlib inline
